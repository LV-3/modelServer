# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/hyeongihong/Documents/lv3_fastapi/app/resources/VODs_1210_1116.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11397 entries, 0 to 11396
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   series_nm              7529 non-null   object
#  1   super_asset_nm         9082 non-null   object
#  2   asset_nm               4206 non-null   object
#  3   ct_cl                  11397 non-null  object
#  4   genre_of_ct_cl         11397 non-null  object
#  5   SMRY                   11397 non-null  object
#  6   ACTR_DISP              11396 non-null  object
#  7   disp_rtm               10725 non-null  object
#  8   is_series              11397 non-null  int64
#  9   is_vod                 11397 non-null  int64
#  10  is_content             11397 non-null  int64
#  11  content_id             11397 non-null  int64
#  12  ImgUrl                 7528 non-null   object
#  13  grade                  6326 non-null   object
# ...

# %%
concat_tmp = data['template_A'] + data['template_B'] + data['template_C']
content_id = data['content_id']

data_dict = dict(zip(content_id, concat_tmp))

# %%
data_dict
# Out:
# {1: 'thought-provoking, insightful, engaging, informative, relevantcommunication, intellectual, socialissues, insightful, journalismcommunication, change, insight, future, society',
#  2: 'peaceful, transformative, nostalgic, enchanting, heartwarmingromantic, love, rural, city, healingromance, countrygirl, rural, healing, cityman',
#  3: 'heartwarming, thrilling, bittersweet, comediccomedy, romance, action, fantasy, transformationpolice, soulchange, romance, superstar, specialforces',
#  4: 'adventurous, transformative, whimsical, heartwarming, unpredictableadventure, fate, discovery, unexpected, missionprotagonist, story, chance, letter, mission',
#  5: 'immersive, intense, thought-provoking, captivating, investigativein-depth, impartial, honest, journalism, investigativeinvestigation, integrity, witness, journalism, truth',
# ...

# %%
nan_data = [key for key, value in data_dict.items() if pd.isna(value)]

# %%
len(nan_data)
# Out:
# 1658

# %%
import pickle

with open('content_id_template.pkl', 'wb') as file:
    pickle.dump(data_dict, file)

# %%
with open('content_id_template.pkl', 'rb') as file:
    load_dict = pickle.load(file)

type(load_dict)
# Out:
# dict

# %%
ctnt_id = ['4250', '5052', '4252', '5056', '4245', '5053', '4246', '4251', '2002', '4247', '2001', '3169', '7078', '4249', '3167', '5054', '4248', '7091', '7077', '7088', '6506', '3179', '7081', '6585', '1999', '2000', '396', '5055', '7090', '7082', '6494', '7093', '7092', '3180', '6613', '6511', '1116', '6510', '6606', '6605', '6505', '1192', '6299', '6492', '709', '2805', '7087', '6507', '2825', '6612', '2010', '7083', '7079', '6610', '5059', '7089', '2003', '2806', '2365', '6604', '7529', '6490', '6513', '7094', '3774', '2027', '228', '6703', '7086', '2807', '6607', '6277', '2364', '6611', '2819', '4303', '4821', '6281', '2366', '2715', '4538', '6609', '659', '6608', '6702', '2031', '6056', '232']

# %%
tmp_list = []


for item in ctnt_id:
    
    if pd.isna(data_dict.get(item)):
        tmp_list.append(data_dict.get(item).split())

print(tmp_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 5
#       1 tmp_list = []
#       4 for item in ctnt_id:
# ----> 5     tmp_list.append(data_dict.get(item).split())
#       7 print(tmp_list)
#
# AttributeError: 'NoneType' object has no attribute 'split'
